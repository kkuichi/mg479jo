# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('TransformedData/transformed_en_es_t.csv', low_memory = False)
df.head(10)
# Out:
#     sym                     prompt      user countries   days session  \
# 0   1.0            Yo soy un niño.  XEinXf5+        CO  0.003  lesson
# 1   2.0          Yo soy de México.  XEinXf5+        CO  0.005  lesson
# 2   3.0        Mi nombre es Pedro.  XEinXf5+        CO  0.008  lesson
# 3   4.0          Ella es una niña.  XEinXf5+        CO  0.008  lesson
# 4   5.0            ¿Él es un niño?  XEinXf5+        CO  0.008  lesson
# 5   6.0       Yo necesito un taxi.  XEinXf5+        CO  0.011  lesson
# 6   7.0                    ¿Dónde?  XEinXf5+        CO  0.011  lesson
# 7   8.0  Yo tengo una reservación.  XEinXf5+        CO  0.016  lesson
# 8   9.0             Yo estoy bien.  XEinXf5+        CO  0.016  lesson
# 9  10.0                             XEinXf5+        CO  0.018  lesson
#
#               format  time token_1 token_10 token_11 token_12 token_13  \
# 0  reverse_translate   9.0       I      NaN      NaN      NaN      NaN
# ...

# %%
df = df.drop('sym', axis = 1)

# %%
df.head(10)
# Out:
#                       prompt      user countries   days session  \
# 0            Yo soy un niño.  XEinXf5+        CO  0.003  lesson
# 1          Yo soy de México.  XEinXf5+        CO  0.005  lesson
# 2        Mi nombre es Pedro.  XEinXf5+        CO  0.008  lesson
# 3          Ella es una niña.  XEinXf5+        CO  0.008  lesson
# 4            ¿Él es un niño?  XEinXf5+        CO  0.008  lesson
# 5       Yo necesito un taxi.  XEinXf5+        CO  0.011  lesson
# 6                    ¿Dónde?  XEinXf5+        CO  0.011  lesson
# 7  Yo tengo una reservación.  XEinXf5+        CO  0.016  lesson
# 8             Yo estoy bien.  XEinXf5+        CO  0.016  lesson
# 9                             XEinXf5+        CO  0.018  lesson
#
#               format  time token_1 token_10 token_11 token_12 token_13  \
# 0  reverse_translate   9.0       I      NaN      NaN      NaN      NaN
# 1  reverse_translate  12.0       I      NaN      NaN      NaN      NaN
# ...

# %%
df = df.loc[:,['prompt','user','countries', 'days', 'session', 'format', 'time',
          'token_1', 'pos_1', 'morf_1', 'accuracy_1', 'case_1', 'gender_1', 'number_1', 'person_1', 'tense_1', 'pronType_1',
          'token_2', 'pos_2', 'morf_2', 'accuracy_2', 'case_2', 'gender_2', 'number_2', 'person_2', 'tense_2', 'pronType_2',
          'token_3', 'pos_3', 'morf_3', 'accuracy_3', 'case_3', 'gender_3', 'number_3', 'person_3', 'tense_3', 'pronType_3',
          'token_4', 'pos_4', 'morf_4', 'accuracy_4', 'case_4', 'gender_4', 'number_4', 'person_4', 'tense_4', 'pronType_4',
          'token_5', 'pos_5', 'morf_5', 'accuracy_5', 'case_5', 'gender_5', 'number_5', 'person_5', 'tense_5', 'pronType_5',
          'token_6', 'pos_6', 'morf_6', 'accuracy_6', 'case_6', 'gender_6', 'number_6', 'person_6', 'tense_6', 'pronType_6',
          'token_7', 'pos_7', 'morf_7', 'accuracy_7', 'case_7', 'gender_7', 'number_7', 'person_7', 'tense_7', 'pronType_7',
          'token_8', 'pos_8', 'morf_8', 'accuracy_8', 'case_8', 'gender_8', 'number_8', 'person_8', 'tense_8', 'pronType_8',
          'token_9', 'pos_9', 'morf_9', 'accuracy_9', 'case_9', 'gender_9', 'number_9', 'person_9', 'tense_9', 'pronType_9',
          'token_10', 'pos_10', 'morf_10', 'accuracy_10', 'case_10', 'gender_10', 'number_10', 'person_10', 'tense_10', 'pronType_10',
          'token_11', 'pos_11', 'morf_11', 'accuracy_11', 'case_11', 'gender_11', 'number_11', 'person_11', 'tense_11', 'pronType_11',
          'token_12', 'pos_12', 'morf_12', 'accuracy_12', 'case_12', 'gender_12', 'number_12', 'person_12', 'tense_12', 'pronType_12',
          'token_13', 'pos_13', 'morf_13', 'accuracy_13', 'case_13', 'gender_13', 'number_13', 'person_13', 'tense_13', 'pronType_13',
          'token_14', 'pos_14', 'morf_14', 'accuracy_14', 'case_14', 'gender_14', 'number_14', 'person_14', 'tense_14', 'pronType_14'
         ]]

# %%
df.head(5)
# Out:
#                 prompt      user countries   days session             format  \
# 0      Yo soy un niño.  XEinXf5+        CO  0.003  lesson  reverse_translate
# 1    Yo soy de México.  XEinXf5+        CO  0.005  lesson  reverse_translate
# 2  Mi nombre es Pedro.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 3    Ella es una niña.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 4      ¿Él es un niño?  XEinXf5+        CO  0.008  lesson  reverse_translate
#
#    time token_1 pos_1     morf_1  morf2_1  accuracy_1 case_1 gender_1  \
# 0   9.0       I  PRON      nsubj      4.0         0.0    Nom      NaN
# 1  12.0       I  PRON      nsubj      4.0         0.0    Nom      NaN
# 2   6.0      My  PRON  nmod:poss      2.0         0.0    NaN      NaN
# 3  13.0     She  PRON      nsubj      4.0         0.0    NaN      NaN
# 4  16.0      Is  VERB        cop      4.0         0.0    NaN      NaN
#
#   number_1  person_1 tense_1 pronType_1  personType_1 token_2 pos_2 morf_2  \
# ...

# %%
for index, line in df.iterrows():
    if np.isnan(df.loc[index, 'accuracy_1']) == False:
        df.loc[index, 'accuracy_1'] = int(df.loc[index, 'accuracy_1'])

    if np.isnan(df.loc[index, 'accuracy_2']) == False:
        df.loc[index, 'accuracy_2'] = int(df.loc[index, 'accuracy_2'])

    if np.isnan( df.loc[index, 'accuracy_3']) == False:
        df.loc[index, 'accuracy_3'] = int(df.loc[index, 'accuracy_3'])

    if np.isnan(df.loc[index, 'accuracy_4']) == False:
        df.loc[index, 'accuracy_4'] = int(df.loc[index, 'accuracy_4'])

    if np.isnan(df.loc[index, 'accuracy_5']) == False:
        df.loc[index, 'accuracy_5'] = int(df.loc[index, 'accuracy_5'])

    if np.isnan(df.loc[index, 'accuracy_6']) == False:
        df.loc[index, 'accuracy_6'] = int(df.loc[index, 'accuracy_6'])

    if np.isnan(df.loc[index, 'accuracy_7']) == False:
        df.loc[index, 'accuracy_7'] = int(df.loc[index, 'accuracy_7'])

    if np.isnan(df.loc[index, 'accuracy_8']) == False:
        df.loc[index, 'accuracy_8'] = int(df.loc[index, 'accuracy_8'])

    if np.isnan(df.loc[index, 'accuracy_9']) == False:
        df.loc[index, 'accuracy_9'] = int(df.loc[index, 'accuracy_9'])

    if np.isnan(df.loc[index, 'accuracy_10']) == False:
        df.loc[index, 'accuracy_10'] = int(df.loc[index, 'accuracy_10'])

    if np.isnan(df.loc[index, 'accuracy_11']) == False:
        df.loc[index, 'accuracy_11'] = int(df.loc[index, 'accuracy_11'])

    if np.isnan(df.loc[index, 'accuracy_12']) == False:
        df.loc[index, 'accuracy_12'] = int(df.loc[index, 'accuracy_12'])

    if np.isnan(df.loc[index, 'accuracy_13']) == False:
        df.loc[index, 'accuracy_13'] = int(df.loc[index, 'accuracy_13'])

    if np.isnan(df.loc[index, 'accuracy_14']) == False:
        df.loc[index, 'accuracy_14'] = int(df.loc[index, 'accuracy_14'])

# %%
df.head(5)
# Out:
#                 prompt      user countries   days session             format  \
# 0      Yo soy un niño.  XEinXf5+        CO  0.003  lesson  reverse_translate
# 1    Yo soy de México.  XEinXf5+        CO  0.005  lesson  reverse_translate
# 2  Mi nombre es Pedro.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 3    Ella es una niña.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 4      ¿Él es un niño?  XEinXf5+        CO  0.008  lesson  reverse_translate
#
#    time token_1 pos_1     morf_1  accuracy_1 case_1 gender_1 number_1  \
# 0   9.0       I  PRON      nsubj         0.0    Nom      NaN     Sing
# 1  12.0       I  PRON      nsubj         0.0    Nom      NaN     Sing
# 2   6.0      My  PRON  nmod:poss         0.0    NaN      NaN     Sing
# 3  13.0     She  PRON      nsubj         0.0    NaN      NaN     Sing
# 4  16.0      Is  VERB        cop         0.0    NaN      NaN     Sing
#
#    person_1 tense_1 pronType_1 token_2 pos_2 morf_2  accuracy_2 case_2  \
# ...

# %%
columns = ['accuracy_1', 'accuracy_2', 'accuracy_3', 'accuracy_4', 'accuracy_5', 'accuracy_6', 'accuracy_7', 'accuracy_8',
           'accuracy_9', 'accuracy_10', 'accuracy_11', 'accuracy_12', 'accuracy_13', 'accuracy_14']
df['acc_sum'] = df[columns].sum(axis = 1)
df.head(5)
# Out:
#                 prompt      user countries   days session             format  \
# 0      Yo soy un niño.  XEinXf5+        CO  0.003  lesson  reverse_translate
# 1    Yo soy de México.  XEinXf5+        CO  0.005  lesson  reverse_translate
# 2  Mi nombre es Pedro.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 3    Ella es una niña.  XEinXf5+        CO  0.008  lesson  reverse_translate
# 4      ¿Él es un niño?  XEinXf5+        CO  0.008  lesson  reverse_translate
#
#    time token_1 pos_1     morf_1  accuracy_1 case_1 gender_1 number_1  \
# 0   9.0       I  PRON      nsubj         0.0    Nom      NaN     Sing
# 1  12.0       I  PRON      nsubj         0.0    Nom      NaN     Sing
# 2   6.0      My  PRON  nmod:poss         0.0    NaN      NaN     Sing
# 3  13.0     She  PRON      nsubj         0.0    NaN      NaN     Sing
# 4  16.0      Is  VERB        cop         0.0    NaN      NaN     Sing
#
#    person_1 tense_1 pronType_1 token_2 pos_2 morf_2  accuracy_2 case_2  \
# ...

# %%
df.tail(20)
# Out:
#                            prompt      user countries   days session  \
# 46491                              kqASumTJ        AR  1.063  lesson
# 46492      Un momento, por favor.  kqASumTJ        AR  1.063  lesson
# 46493               Buenas noches  kqASumTJ        AR  1.064  lesson
# 46494                   La década  kqASumTJ        AR  1.064  lesson
# 46495          Minutos y segundos  kqASumTJ        AR  1.064  lesson
# 46496                    El autor  kqASumTJ        AR  1.172  lesson
# 46497      ¿Quién es el director?  kqASumTJ        AR  1.172  lesson
# 46498          Yo amo mi carrera.  kqASumTJ        AR  1.172  lesson
# 46499         Yo soy el director.  kqASumTJ        AR  1.172  lesson
# 46500                  El abogado  kqASumTJ        AR  1.175  lesson
# 46501  ¿Dónde está mi secretaria?  kqASumTJ        AR  1.175  lesson
# 46502                  El capitán  kqASumTJ        AR  1.176  lesson
# 46503                  Los jueces  kqASumTJ        AR  1.176  lesson
# ...

# %%
df.loc[df['acc_sum'] > 1, 'acc_sum'] = 1

# %%
df.tail(10)
# Out:
#                            prompt      user countries   days session  \
# 46501  ¿Dónde está mi secretaria?  kqASumTJ        AR  1.175  lesson
# 46502                  El capitán  kqASumTJ        AR  1.176  lesson
# 46503                  Los jueces  kqASumTJ        AR  1.176  lesson
# 46504           Tú eres bilingüe.  kqASumTJ        AR  1.179  lesson
# 46505             ¿Estás cansado?  kqASumTJ        AR  1.179  lesson
# 46506             La misma comida  kqASumTJ        AR  1.179  lesson
# 46507            Él está cansado.  kqASumTJ        AR  1.179  lesson
# 46508               La misma sopa  kqASumTJ        AR  1.179  lesson
# 46509                              kqASumTJ        AR  1.182  lesson
# 46510            Fiestas privadas  kqASumTJ        AR  1.182  lesson
#
#                   format  time  token_1 pos_1 morf_1  accuracy_1 case_1  \
# 46501  reverse_translate  12.0    Where   ADV   ROOT         0.0    NaN
# ...

# %%
cols = ['accuracy_1', 'accuracy_2', 'accuracy_3', 'accuracy_4', 'accuracy_5', 'accuracy_6', 'accuracy_7', 'accuracy_8',
           'accuracy_9', 'accuracy_10', 'accuracy_11', 'accuracy_12', 'accuracy_13', 'accuracy_14']
df = df.drop(cols, axis = 1)

# %%
df.to_csv('TransformedData/en.csv', sep = ',', index = False, encoding='utf-8')

# %%
df = pd.read_csv('TransformedData/transformed_es_en_t.csv', low_memory = False)
df = df.drop('sym', axis = 1)

df = df.loc[:,['prompt','user','countries', 'days', 'session', 'format', 'time',
          'token_1', 'pos_1', 'morf_1', 'accuracy_1', 'case_1', 'gender_1', 'number_1', 'person_1', 'tense_1', 'pronType_1',
          'token_2', 'pos_2', 'morf_2', 'accuracy_2', 'case_2', 'gender_2', 'number_2', 'person_2', 'tense_2', 'pronType_2',
          'token_3', 'pos_3', 'morf_3', 'accuracy_3', 'case_3', 'gender_3', 'number_3', 'person_3', 'tense_3', 'pronType_3',
          'token_4', 'pos_4', 'morf_4', 'accuracy_4', 'case_4', 'gender_4', 'number_4', 'person_4', 'tense_4', 'pronType_4',
          'token_5', 'pos_5', 'morf_5', 'accuracy_5', 'case_5', 'gender_5', 'number_5', 'person_5', 'tense_5', 'pronType_5',
          'token_6', 'pos_6', 'morf_6', 'accuracy_6', 'case_6', 'gender_6', 'number_6', 'person_6', 'tense_6', 'pronType_6',
          'token_7', 'pos_7', 'morf_7', 'accuracy_7', 'case_7', 'gender_7', 'number_7', 'person_7', 'tense_7', 'pronType_7',
          'token_8', 'pos_8', 'morf_8', 'accuracy_8', 'case_8', 'gender_8', 'number_8', 'person_8', 'tense_8', 'pronType_8',
          'token_9', 'pos_9', 'morf_9', 'accuracy_9', 'case_9', 'gender_9', 'number_9', 'person_9', 'tense_9', 'pronType_9',
          'token_10', 'pos_10', 'morf_10', 'accuracy_10', 'case_10', 'gender_10', 'number_10', 'person_10', 'tense_10', 'pronType_10',
          'token_11', 'pos_11', 'morf_11', 'accuracy_11', 'case_11', 'gender_11', 'number_11', 'person_11', 'tense_11', 'pronType_11',
          'token_12', 'pos_12', 'morf_12', 'accuracy_12', 'case_12', 'gender_12', 'number_12', 'person_12', 'tense_12', 'pronType_12'
         ]]


for index, line in df.iterrows():
    if np.isnan(df.loc[index, 'accuracy_1']) == False:
        df.loc[index, 'accuracy_1'] = int(df.loc[index, 'accuracy_1'])

    if np.isnan(df.loc[index, 'accuracy_2']) == False:
        df.loc[index, 'accuracy_2'] = int(df.loc[index, 'accuracy_2'])

    if np.isnan( df.loc[index, 'accuracy_3']) == False:
        df.loc[index, 'accuracy_3'] = int(df.loc[index, 'accuracy_3'])

    if np.isnan(df.loc[index, 'accuracy_4']) == False:
        df.loc[index, 'accuracy_4'] = int(df.loc[index, 'accuracy_4'])

    if np.isnan(df.loc[index, 'accuracy_5']) == False:
        df.loc[index, 'accuracy_5'] = int(df.loc[index, 'accuracy_5'])

    if np.isnan(df.loc[index, 'accuracy_6']) == False:
        df.loc[index, 'accuracy_6'] = int(df.loc[index, 'accuracy_6'])

    if np.isnan(df.loc[index, 'accuracy_7']) == False:
        df.loc[index, 'accuracy_7'] = int(df.loc[index, 'accuracy_7'])

    if np.isnan(df.loc[index, 'accuracy_8']) == False:
        df.loc[index, 'accuracy_8'] = int(df.loc[index, 'accuracy_8'])

    if np.isnan(df.loc[index, 'accuracy_9']) == False:
        df.loc[index, 'accuracy_9'] = int(df.loc[index, 'accuracy_9'])

    if np.isnan(df.loc[index, 'accuracy_10']) == False:
        df.loc[index, 'accuracy_10'] = int(df.loc[index, 'accuracy_10'])

    if np.isnan(df.loc[index, 'accuracy_11']) == False:
        df.loc[index, 'accuracy_11'] = int(df.loc[index, 'accuracy_11'])

    if np.isnan(df.loc[index, 'accuracy_12']) == False:
        df.loc[index, 'accuracy_12'] = int(df.loc[index, 'accuracy_12'])

columns = ['accuracy_1', 'accuracy_2', 'accuracy_3', 'accuracy_4', 'accuracy_5', 'accuracy_6', 'accuracy_7', 'accuracy_8',
           'accuracy_9', 'accuracy_10', 'accuracy_11', 'accuracy_12']

df['acc_sum'] = df[columns].sum(axis = 1)

df.loc[df['acc_sum'] > 1, 'acc_sum'] = 1

df = df.drop(columns, axis = 1)

df.to_csv('TransformedData/es.csv', sep = ',', index = False, encoding = 'utf-8')

# %%
df = pd.read_csv('TransformedData/transformed_fr_en_t.csv', low_memory = False)

# %%
df.head(10)
# Out:
#     sym            prompt      user countries   days session  \
# 0   1.0           The boy  YjS/mQOx        CA  0.005  lesson
# 1   2.0     I am a woman.  YjS/mQOx        CA  0.005  lesson
# 2   3.0          The girl  YjS/mQOx        CA  0.005  lesson
# 3   4.0       I am a boy.  YjS/mQOx        CA  0.005  lesson
# 4   5.0        I am rich!  YjS/mQOx        CA  0.009  lesson
# 5   6.0         I am red!  YjS/mQOx        CA  0.009  lesson
# 6   7.0           The man  YjS/mQOx        CA  0.009  lesson
# 7   8.0  The man is rich.  YjS/mQOx        CA  0.009  lesson
# 8   9.0          An apple  YjS/mQOx        CA  0.009  lesson
# 9  10.0    You are a boy.  YjS/mQOx        CA  0.009  lesson
#
#               format  time token_1 token_10 token_11 token_12 token_2 token_3  \
# 0  reverse_translate  14.0      Le      NaN      NaN      NaN  garçon     NaN
# 1  reverse_translate  14.0      Je      NaN      NaN      NaN    suis     une
# ...

# %%
df = df.drop('sym', axis = 1)
df = df.loc[:,['prompt','user','countries', 'days', 'session', 'format', 'time',
          'token_1', 'pos_1', 'morf_1', 'accuracy_1', 'case_1', 'gender_1', 'number_1', 'person_1', 'tense_1', 'pronType_1',
          'token_2', 'pos_2', 'morf_2', 'accuracy_2', 'case_2', 'gender_2', 'number_2', 'person_2', 'tense_2', 'pronType_2',
          'token_3', 'pos_3', 'morf_3', 'accuracy_3', 'case_3', 'gender_3', 'number_3', 'person_3', 'tense_3', 'pronType_3',
          'token_4', 'pos_4', 'morf_4', 'accuracy_4', 'case_4', 'gender_4', 'number_4', 'person_4', 'tense_4', 'pronType_4',
          'token_5', 'pos_5', 'morf_5', 'accuracy_5', 'case_5', 'gender_5', 'number_5', 'person_5', 'tense_5', 'pronType_5',
          'token_6', 'pos_6', 'morf_6', 'accuracy_6', 'case_6', 'gender_6', 'number_6', 'person_6', 'tense_6', 'pronType_6',
          'token_7', 'pos_7', 'morf_7', 'accuracy_7', 'case_7', 'gender_7', 'number_7', 'person_7', 'tense_7', 'pronType_7',
          'token_8', 'pos_8', 'morf_8', 'accuracy_8', 'case_8', 'gender_8', 'number_8', 'person_8', 'tense_8', 'pronType_8',
          'token_9', 'pos_9', 'morf_9', 'accuracy_9', 'case_9', 'gender_9', 'number_9', 'person_9', 'tense_9', 'pronType_9',
          'token_10', 'pos_10', 'morf_10', 'accuracy_10', 'case_10', 'gender_10', 'number_10', 'person_10', 'tense_10', 'pronType_10',
          'token_11', 'pos_11', 'morf_11', 'accuracy_11', 'case_11', 'gender_11', 'number_11', 'person_11', 'tense_11', 'pronType_11',
          'token_12', 'pos_12', 'morf_12', 'accuracy_12', 'case_12', 'gender_12', 'number_12', 'person_12', 'tense_12', 'pronType_12'
         ]]
for index, line in df.iterrows():
    if np.isnan(df.loc[index, 'accuracy_1']) == False:
        df.loc[index, 'accuracy_1'] = int(df.loc[index, 'accuracy_1'])

    if np.isnan(df.loc[index, 'accuracy_2']) == False:
        df.loc[index, 'accuracy_2'] = int(df.loc[index, 'accuracy_2'])

    if np.isnan( df.loc[index, 'accuracy_3']) == False:
        df.loc[index, 'accuracy_3'] = int(df.loc[index, 'accuracy_3'])

    if np.isnan(df.loc[index, 'accuracy_4']) == False:
        df.loc[index, 'accuracy_4'] = int(df.loc[index, 'accuracy_4'])

    if np.isnan(df.loc[index, 'accuracy_5']) == False:
        df.loc[index, 'accuracy_5'] = int(df.loc[index, 'accuracy_5'])

    if np.isnan(df.loc[index, 'accuracy_6']) == False:
        df.loc[index, 'accuracy_6'] = int(df.loc[index, 'accuracy_6'])

    if np.isnan(df.loc[index, 'accuracy_7']) == False:
        df.loc[index, 'accuracy_7'] = int(df.loc[index, 'accuracy_7'])

    if np.isnan(df.loc[index, 'accuracy_8']) == False:
        df.loc[index, 'accuracy_8'] = int(df.loc[index, 'accuracy_8'])

    if np.isnan(df.loc[index, 'accuracy_9']) == False:
        df.loc[index, 'accuracy_9'] = int(df.loc[index, 'accuracy_9'])

    if np.isnan(df.loc[index, 'accuracy_10']) == False:
        df.loc[index, 'accuracy_10'] = int(df.loc[index, 'accuracy_10'])

    if np.isnan(df.loc[index, 'accuracy_11']) == False:
        df.loc[index, 'accuracy_11'] = int(df.loc[index, 'accuracy_11'])

    if np.isnan(df.loc[index, 'accuracy_12']) == False:
        df.loc[index, 'accuracy_12'] = int(df.loc[index, 'accuracy_12'])

columns = ['accuracy_1', 'accuracy_2', 'accuracy_3', 'accuracy_4', 'accuracy_5', 'accuracy_6', 'accuracy_7', 'accuracy_8',
           'accuracy_9', 'accuracy_10', 'accuracy_11', 'accuracy_12']

df['acc_sum'] = df[columns].sum(axis = 1)

df.loc[df['acc_sum'] > 1, 'acc_sum'] = 1

df = df.drop(columns, axis = 1)

df.to_csv('TransformedData/fr.csv', sep = ',', index=False, encoding='utf-8')
